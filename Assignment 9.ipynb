# %%
def Strength(password):
    special_char="!@#$%^&*()_+=<>?:'"

    if len(password)<8:
        return"in vailid password , it must have 8 letters"
    if not any(char.isdigit() for char in password):
        return"password must have one digit"
    if not any(char in special_char for char in password):
        return"Password must have one Special charecter"
    return"It is strength password"
    
password=input("Enter your password:")
Strength(password)
# Out:
# Enter your password: Somanath@123
# 'It is strength password'
