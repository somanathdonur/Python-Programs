# %%
name=input("Enter the name:")
age=int(input("Enter the your age:"))
email=input("Enter your email:")
phoneNo=input("Enter your number:")
percentage=float(input("Enter your perstentage:"))

print("****VALIDATION STUDENT Impormation****")

if age<18:
    print("Rejection the student details age must be equle to 18 or above")
elif percentage<60:
    print("Rejection the student details percentage must be equle to 60 or above")
elif len(phoneNo) !=10 or not phoneNo.isdigit():
    print("Rejection the student details age must be equle to 10 digit number")
else:
    print("Student is eligible for internship")
# Out:
# Enter the name: Somanath
# Enter the your age: 17
# Enter your email: somanathdonur18124791@gmail.com
# Enter your number: 8217592183
# Enter your perstentage: 40.09
# ****VALIDATION STUDENT Impormation****
# Rejection the student details age must be equle to 18 or above
