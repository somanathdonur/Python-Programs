# %%
def eligible(age,percentage):
    if age>=18:
        if percentage>=60:
            print("student is Eligibale for Addmition")
    else:
        print("Student is not Eligible For Addmition")
ages=int(input("Enter Your AGE:"))
percentage=float(input("Enter your PERCENTAGE:"))
abs=eligible(ages,percentage)
# Out:
# Enter Your AGE 18
# Enter your percentage 60
# student is Eligibale for Addmition
