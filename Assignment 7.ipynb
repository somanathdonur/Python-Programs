# %%
def attendance(time):
    if "9:30"==time:
        print("Student in on time And 'PRESENT'")
    elif "10:00"<time:
        print("Student  is 'LEAT'")
    else:
        print("Student is not on time 'ABSENT'")

time=input("Enter your time For Entry:")
attendance(time)
# Out:
# Enter your time For Entry: 9:46
# Student  is 'LEAT'
